# %%
import spacy

import re
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import nltk
import json

from spacy.language import Language
from typing import Dict, List, Set, Tuple
from collections import defaultdict, namedtuple
import copy
from statistics import mean 
import io
from PIL import Image, ImageDraw, ImageFont
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from google.protobuf.json_format import MessageToJson, Parse
from google.protobuf import json_format

import os
import sys
sys.path.append("../../")
from models.dish_segmenter import Dish
from models.bounding_box import FeatureType, Point, BoundingBox, DSU
from models.word_unit import WordUnit
from utils.cv_preprocess import *
from utils.file_utils import *
from utils.nlp_preprocess import *
from IPython.display import display

# %%
from sentence_transformers import SentenceTransformer, util

# Initialize the model, using a pre-trained transformer. This only needs to be done once.
model = SentenceTransformer('all-MiniLM-L6-v2')

def calculate_semantic_correlation(text1, text2, penalization_factor=0):
    """
    Calculate semantic correlation between two pieces of text.

    Args:
    text1 (str): First text to be compared.
    text2 (str): Second text to be compared.

    Returns:
    float: A semantic correlation score between 0 and 1, where 1 means very high similarity.
    """
    if text1.strip() == "" or text2.strip() == "":
        # Return a penalized score for cases with empty text
        return penalization_factor
    # Generate the embeddings for both texts
    embedding1 = model.encode(text1, convert_to_tensor=True)
    embedding2 = model.encode(text2, convert_to_tensor=True)
    
    # Compute cosine similarity between the embeddings
    cosine_scores = util.pytorch_cos_sim(embedding1, embedding2)
    
    # Return the cosine similarity score as a float
    return cosine_scores.item()

# %%
calculate_semantic_correlation("鸡", "vegetable")
# Out:
# 0.15781274437904358

# %%
calculate_semantic_correlation("鸡", "")
# Out:
# 0

# %%
def process_menu(filein):
    base_name = os.path.basename(filein)
    file_name_without_extension = os.path.splitext(base_name)[0]

    raw_ocr_directory = '../../dataset/menu_photo_ocr_raw/'
    raw_ocr_filename = file_name_without_extension + "_raw_annotation.json"
    raw_ocr_path = os.path.join(raw_ocr_directory, raw_ocr_filename)

    document = load_json(raw_ocr_path)
    image = Image.open(filein)
    
    

    bounds = process_bounds_in_words(document)
    

    price_bounds = extract_price_bounds(bounds)
    filtered_bounds, chinese_bbox, english_bbox = filter_and_classify_bounds(bounds)

    locator_bounds = [price_bounds, chinese_bbox]

    overlap_threshold_list = [0.3, 0.4, 0.5]

    container_width, container_height = image.size
    
    # loop through all possible extend directions
    extend_directions_pair = [[ExtendDirection.BOTTOM, ExtendDirection.LEFT], [ExtendDirection.BOTTOM, ExtendDirection.RIGHT], [ExtendDirection.TOP, ExtendDirection.LEFT], [ExtendDirection.TOP, ExtendDirection.RIGHT]]
    
    # find the extend direction that have the highest semantic correlation in chinese and english
    max_correlation = 0
    max_correlation_pair = None
    max_locator = None
    max_overlap = 0
    max_avg_correlation = 0

    max_grouped_list, max_grouped_box = None, None  
    for overlap_threshold in overlap_threshold_list:
        for locator_bound in locator_bounds:
            for extend_directions in extend_directions_pair:
                # print()
                # print("Processing", extend_directions)
                extended_boxes = extend_bounding_boxes(locator_bound, container_width, container_height, extend_directions=extend_directions)
                sorted_bounding_boxes = sorted(filtered_bounds, key=lambda bbox: (bbox.y_min, bbox.x_min))
                grouped_list, grouped_box = group_extended_boxes(extended_boxes, sorted_bounding_boxes, overlap_threshold=overlap_threshold)
                
                total_correlation = 0
                correlation_count = 0
                for string_list in grouped_list:
                    # flatten the list of strings by joining them
                    string_list = [" ".join(string) for string in string_list if string != ""]
                    
                    chinese_text, english_text = split_chinese_english(string_list)
                    chinese_text = "".join(chinese_text)
                    english_text = " ".join(english_text)
                    
                    correlation = calculate_semantic_correlation(chinese_text, english_text)
                    # print(chinese_text, english_text, correlation)
                    total_correlation += correlation
                    correlation_count += 1
                
                # Calculate average correlation if there are valid correlations
                if correlation_count > 0:
                    # avg_correlation = total_correlation / correlation_count
                    if total_correlation > max_avg_correlation:
                        max_avg_correlation = total_correlation
                        max_correlation_pair = extend_directions
                        max_grouped_list = grouped_list
                        max_grouped_box = grouped_box
                        max_locator = locator_bound
                        max_overlap = overlap_threshold
    

    draw_boxes_2_points(image, max_grouped_box, (255, 0, 0))
    plt.figure(figsize=(10, 10))
    display(image)
    
    dish_instance_list = []
    
    for string_list in max_grouped_list:
        # print(string_list)
        dish = segment_dish_text_list(string_list)
        print(dish)
        dish_instance_list.append(dish)

# Usage example
# filein = '../../dataset/menu_photo/8._New_Fortune_Cookie_0_page_5.png'
# filein = '../../dataset/menu_photo/menu-2023_page_1.png'
filein = '../../dataset/menu_photo/Rendezvous_sit-in_08-23_Draft_page_2.png'
# filein = '../../dataset/menu_photo/jimmy_express_4.png'
# filein = '../../dataset/menu_photo/barshu (4).png'


process_menu(filein)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2481x3508>
# Chinese Name: ['湯類']
# English Name: ['SOUP']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['蘑菇', '雞', '片', '湯']
# English Name: ['Chicken', 'Mushroom', 'Soup']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['雞', '麵湯']
# English Name: ['Chicken', 'Noodle', 'Soup']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['蛋花湯']
# English Name: ['Egg', 'and', 'Tomato', 'Soup']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['雜', '菜湯']
# English Name: ['Mixed', 'Vegetable', 'Soup']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['豆腐', '雜', '菜湯']
# English Name: ['4A']
# Chinese Description: []
# English Description: [['Bean', 'Curd', 'and', 'Vegetable', 'Soup']]
#
# Chinese Name: ['蟹肉', '粟米', '湯']
# English Name: ['Crab', 'Meat', 'and', 'Sweetcorn', 'Soup']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['雞肉', '粟米', '湯']
# English Name: ['5A']
# Chinese Description: []
# English Description: [['Mashed', 'Chicken', 'and', 'Sweetcorn', 'Soup']]
#
# Chinese Name: ['酸辣', '湯']
# English Name: ['Hot', 'and', 'Sour', 'Soup']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['東', '央', '湯']
# English Name: ['Tom', 'Yum', 'Soup', 'Thai', 'hot', 'and', 'spicy']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['西湖', '牛肉', '湯']
# English Name: ['Beef', 'West', 'Lake', 'Soup']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['魚片', '粉絲', '湯']
# English Name: ['10A']
# Chinese Description: []
# English Description: [['Fish', 'with', 'Bean', 'Vermicelli', 'Soup']]
#
# Chinese Name: ['雲吞', '湯']
# English Name: []
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['頭', '盤']
# English Name: ['APPETISERS']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['拼盤']
# English Name: ['MIX']
# Chinese Description: []
# English Description: [['Mixed', 'Starter', 'for', 'People'], ['Per', 'Head']]
#
# Chinese Name: ['海鲜', '拼盤']
# English Name: ['MS']
# Chinese Description: []
# English Description: [['Seafood', 'Mixed', 'Starter', 'for', 'People', 'Per', 'Head']]
#
# Chinese Name: ['蝦', '多', '士']
# English Name: ['Fried', 'Mashed', 'Prawn', 'on', 'Toast', 'with', 'Sesame', 'Seeds']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['炸', '二', '松']
# English Name: ['12A']
# Chinese Description: []
# English Description: [['Crispy', 'Green', 'Seaweed']]
#
# Chinese Name: ['紙包', '蝦']
# English Name: ['Deep', 'Fried', 'Wafer', 'Wrapped', 'King', 'Prawn']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['紙包', '牛']
# English Name: ['13B', 'Deep', 'Fried', 'Wafer', 'Wrapped', 'Beef']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['紙包', '雞']
# English Name: ['13C', 'Deep', 'Fried', 'Wafer', 'Wrapped', 'Chicken']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['蝴蝶', '蝦']
# English Name: ['15K', 'Butterfly', 'King', 'Prawn', 'dip', 'in', 'sauce']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['蝴蝶', '雞']
# English Name: ['15C']
# Chinese Description: []
# English Description: [['Butterfly', 'Chicken', 'dip', 'in', 'sauce']]
#
# Chinese Name: ['蝦', '喀']
# English Name: ['Prawn', 'Cocktail']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['炸', '雲吞']
# English Name: ['Crispy', 'Wun', 'Tun', 'dip', 'in', 'sauce']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['燒賣']
# English Name: ['Shiu', 'Mai', 'streamed', 'chopped', 'pork', 'and', 'Prawns']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['椒鹽', '雞翅']
# English Name: ['23C', 'Spicy', 'Chicken', 'Wings']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['明蝦', '餃']
# English Name: ['Har', 'Kau', 'steamed', 'prawns']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['蜜汁', '排骨']
# English Name: ['Honey', 'Spare', 'Ribs']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['紅燒', '排骨']
# English Name: ['Barbecued', 'Spare', 'Ribs', 'with', 'Peking', 'Sauce']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['干炸', '排骨']
# English Name: ['Barbecued', 'Spare', 'Ribs', 'no', 'sauce']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['椒鹽', '排骨']
# English Name: ['42A']
# Chinese Description: []
# English Description: [['Spicy', 'Ribs']]
#
# Chinese Name: ['鼓', '汁', '蒸', '帶子']
# English Name: ['Steamed', 'Scallops', 'with', 'Black', 'Bean', 'Sauce']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['鼓', '汁', '青', '口']
# English Name: ['Mussels', 'with', 'Black', 'Bean', 'Sauce']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['春卷']
# English Name: ['Spring', 'Roll']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['齋', '春卷']
# English Name: ['65V', 'Vegetarian', 'Spring', 'Roll']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['鸭', '絲', '卷']
# English Name: ['Crispy', 'Duck', 'Roll']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['越南', '春卷']
# English Name: ['65N', 'Vietnamese', 'Spring', 'Roll']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['沙爹', '雞', '串']
# English Name: ['21C', 'Sizzling', 'Satay', 'Chicken', 'Skewers']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['沙爹', '牛', '串']
# English Name: ['21B', 'Sizzling', 'Satay', 'Beef', 'Skewers']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['沙爹', '大蝦', '串']
# English Name: ['Sizzling', 'Satay', 'King', 'Prawn', 'Skewers']
# Chinese Description: []
# English Description: []
#
# Chinese Name: ['椒鹽', '雞絲']
# English Name: ['Salt', 'and', 'Pepper', 'Crispy', 'Shredded', 'Chicken']
# Chinese Description: []
# English Description: []
