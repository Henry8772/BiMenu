# %%
from collections import namedtuple
from PIL import Image, ImageDraw, ImageFont
from google.cloud import vision
from enum import Enum
# %matplotlib inline
import matplotlib.pyplot as plt
import os
import json
from google.protobuf.json_format import MessageToJson
from google.protobuf import json_format

import sys
sys.path.append("../../")
from models.bounding_box import FeatureType, Point, BoundingBox
from utils.cv_preprocess import draw_boxes, group_bounding_boxes, merge_box_groups

from utils.file_utils import prepare_image_local, prepare_image_web, load_counter, save_counter, save_json

from utils.nlp_preprocess import *

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '../../menu-ocr-390814-99b5549068a5.json'

# %%
# Directory containing images
image_directory = '../../dataset/menu_photo/'

# Directories for storing OCR data
raw_ocr_directory = '../../dataset/menu_photo_ocr_raw/'

# %%
# Initialize Google Cloud Vision client
client = vision.ImageAnnotatorClient()

# Traverse through all images in the directory
for file_name in os.listdir(image_directory):
    if file_name.endswith('.png') or file_name.endswith('.jpg') or file_name.endswith('.webp'):
        file_path = os.path.join(image_directory, file_name)
        file_name_without_extension = os.path.splitext(file_name)[0]

        # Construct raw OCR file path
        raw_ocr_filename = file_name_without_extension + "_raw_annotation.json"
        raw_ocr_path = os.path.join(raw_ocr_directory, raw_ocr_filename)

        # Check if OCR file already exists
        if os.path.exists(raw_ocr_path):
            print(f'{raw_ocr_path} exists, move to next one')
            continue

        # Prepare image for OCR
        image = prepare_image_local(file_path)

        # Perform OCR
        response = client.document_text_detection(
            image=image, 
            image_context={"language_hints": ["zh", "en"]}
        )

        # Convert OCR response to JSON
        document_json = MessageToJson(response.full_text_annotation._pb)

        # Create directory if it doesn't exist
        if not os.path.exists(raw_ocr_directory):
            os.makedirs(raw_ocr_directory)

        # Save OCR data to file
        with open(raw_ocr_path, 'w', encoding='utf-8') as json_file:
            json_file.write(document_json)

        # Load, increment, and save the counter
        current_count = load_counter()
        current_count += 1
        save_counter(current_count)
# Out:
# ../../dataset/menu_photo_ocr_raw/54120_7163702_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/Home Manc Menu (1)-compressed_page_21_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/9._Crystal_China_18_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/3._Chop_Chop_1_segment_1_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/RCC_A la Carte Menu_page_0_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/110._Bright_Courtyard_4_page_2_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/2023-a-la-carte-menu-264_page_2_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/54120_7163689_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/plates2-1920w_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/Rendezvous_sit-in_08-23_Draft_page_9_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/menu-final_page_15_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/menu-final_page_14_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/Rendezvous_sit-in_08-23_Draft_page_8_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/rest (2)_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/barshu (10)_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/2023-a-la-carte-menu-264_page_3_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/barshu (2)_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/menu_sitin_s02-600x851_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/RCC_A la Carte Menu_page_1_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/3._Chop_Chop_1_segment_0_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/Home Manc Menu (1)-compressed_page_20_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/54120_7163703_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/Home Manc Menu (1)-compressed_page_22_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/54120_7163701_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/5._Ma_La_Sichuan_0_page_8_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/3._Chop_Chop_1_segment_2_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/RCC_A la Carte Menu_page_3_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/8._New_Fortune_Cookie_0_page_8_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/2023-a-la-carte-menu-264_page_1_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/1080X1920-07-1920w_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/menu-final_page_16_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/menu-final_page_17_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/2023-a-la-carte-menu-264_page_0_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/eb1734_75e0771090a0453f8329aff37534cf4d~mv2_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/RCC_A la Carte Menu_page_2_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/MainMenu_en_13_page_8_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/3._Chop_Chop_1_segment_3_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/5._Ma_La_Sichuan_0_page_9_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/54120_7163700_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw/Home Manc Menu (1)-compressed_page_23_raw_annotation.json exists, move to next one
# ../../dataset/menu_photo_ocr_raw