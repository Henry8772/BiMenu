# %%
from bs4 import BeautifulSoup
import re
import json

# Provided HTML snippet
html_snippet = '''
<div class="geos_grid">
<div class="geos_row">
<div class="geo_wrap">
<div class="geo_entry">
<div class="geo_info">
<div class="geo_rank">1</div>
<div class="geo_name">
<a href="/Restaurants-g60763-New_York_City_New_York.html">New York City Restaurants</a>
</div>
</div>
<div class="geo_image">
<a href="/Restaurants-g60763-New_York_City_New_York.html">
<div style="position: relative; width: 220px; height: 147px; overflow: hidden;">
<img src="https://media-cdn.tripadvisor.com/media/photo-s/0e/9a/e3/1d/freedom-tower.jpg" width="220" height="183" alt="New York City Restaurants" style="position: absolute; top: -18px; left: -0px; clip: rect(18px 220px 165px 0px);"/>
</div>
</a>
</div>
</div>
</div>
<div class="geo_wrap">
<div class="geo_entry">
<div class="geo_info">
<div class="geo_rank">2</div>
<div class="geo_name">
<a href="/Restaurants-g32655-Los_Angeles_California.html">Los Angeles Restaurants</a>
</div>
</div>
<div class="geo_image">
<a href="/Restaurants-g32655-Los_Angeles_California.html">
<div style="position: relative; width: 220px; height: 147px; overflow: hidden;">
<img src="https://media-cdn.tripadvisor.com/media/photo-s/01/09/97/fe/los-angeles.jpg" width="220" height="182" alt="Los Angeles Restaurants" style="position: absolute; top: -17px; left: -0px; clip: rect(17px 220px 164px 0px);"/>
</div>
</a>
</div>
</div>
</div>
<div class="geo_wrap">
<div class="geo_entry">
<div class="geo_info">
<div class="geo_rank">3</div>
<div class="geo_name">
<a href="/Restaurants-g35805-Chicago_Illinois.html">Chicago Restaurants</a>
</div>
</div>
<div class="geo_image">
<a href="/Restaurants-g35805-Chicago_Illinois.html">
<div style="position: relative; width: 220px; height: 147px; overflow: hidden;">
<img src="https://media-cdn.tripadvisor.com/media/photo-s/07/72/27/a3/chicago.jpg" width="220" height="183" alt="Chicago Restaurants" style="position: absolute; top: -18px; left: -0px; clip: rect(18px 220px 165px 0px);"/>
</div>
</a>
</div>
</div>
</div>
<div class="geo_wrap">
<div class="geo_entry">
<div class="geo_info">
<div class="geo_rank">4</div>
<div class="geo_name">
<a href="/Restaurants-g56003-Houston_Texas.html">Houston Restaurants</a>
</div>
</div>
<div class="geo_image">
<a href="/Restaurants-g56003-Houston_Texas.html">
<div style="position: relative; width: 220px; height: 147px; overflow: hidden;">
<img src="https://media-cdn.tripadvisor.com/media/photo-s/09/d3/cd/ad/houston-downtown-skyline.jpg" width="220" height="192" alt="Houston Restaurants" style="position: absolute; top: -22px; left: -0px; clip: rect(22px 220px 169px 0px);"/>
</div>
</a>
</div>
</div>
</div>
</div> <div class="geos_row">
<div class="geo_wrap">
<div class="geo_entry">
<div class="geo_info">
<div class="geo_rank">5</div>
<div class="geo_name">
<a href="/Restaurants-g60827-Brooklyn_New_York.html">Brooklyn Restaurants</a>
</div>
</div>
<div class="geo_image">
<a href="/Restaurants-g60827-Brooklyn_New_York.html">
<div style="position: relative; width: 220px; height: 147px; overflow: hidden;">
<img src="https://media-cdn.tripadvisor.com/media/photo-s/03/9b/2f/4e/brooklyn.jpg" width="220" height="165" alt="Brooklyn Restaurants" style="position: absolute; top: -9px; left: -0px; clip: rect(9px 220px 156px 0px);"/>
</div>
</a>
</div>
</div>
</div>
<div class="geo_wrap">
<div class="geo_entry">
<div class="geo_info">
<div class="geo_rank">6</div>
<div class="geo_name">
<a href="/Restaurants-g60713-San_Francisco_California.html">San Francisco Restaurants</a>
</div>
</div>
<div class="geo_image">
<a href="/Restaurants-g60713-San_Francisco_California.html">
<div style="position: relative; width: 220px; height: 147px; overflow: hidden;">
<img src="https://media-cdn.tripadvisor.com/media/photo-s/01/70/71/51/the-painted-ladies-of.jpg" width="220" height="206" alt="San Francisco Restaurants" style="position: absolute; top: -29px; left: -0px; clip: rect(29px 220px 176px 0px);"/>
</div>
</a>
</div>
</div>
</div>
<div class="geo_wrap">
<div class="geo_entry">
<div class="geo_info">
<div class="geo_rank">7</div>
<div class="geo_name">
<a href="/Restaurants-g45963-Las_Vegas_Nevada.html">Las Vegas Restaurants</a>
</div>
</div>
<div class="geo_image">
<a href="/Restaurants-g45963-Las_Vegas_Nevada.html">
<div style="position: relative; width: 220px; height: 147px; overflow: hidden;">
<img src="https://media-cdn.tripadvisor.com/media/photo-s/06/73/ad/61/bigphotoforlas-vegas.jpg" width="220" height="165" alt="Las Vegas Restaurants" style="position: absolute; top: -9px; left: -0px; clip: rect(9px 220px 156px 0px);"/>
</div>
</a>
</div>
</div>
</div>
<div class="geo_wrap">
<div class="geo_entry">
<div class="geo_info">
<div class="geo_rank">8</div>
<div class="geo_name">
<a href="/Restaurants-g60795-Philadelphia_Pennsylvania.html">Philadelphia Restaurants</a>
</div>
</div>
<div class="geo_image">
<a href="/Restaurants-g60795-Philadelphia_Pennsylvania.html">
<div style="position: relative; width: 220px; height: 147px; overflow: hidden;">
<img src="https://media-cdn.tripadvisor.com/media/photo-s/01/0e/ca/38/writings-on-the-wall.jpg" width="220" height="206" alt="Philadelphia Restaurants" style="position: absolute; top: -29px; left: -0px; clip: rect(29px 220px 176px 0px);"/>
</div>
</a>
</div>
</div>
</div>
</div> <div class="geos_row">
<div class="geo_wrap">
<div class="geo_entry">
<div class="geo_info">
<div class="geo_rank">9</div>
<div class="geo_name">
<a href="/Restaurants-g60750-San_Diego_California.html">San Diego Restaurants</a>
</div>
</div>
<div class="geo_image">
<a href="/Restaurants-g60750-San_Diego_California.html">
<div style="position: relative; width: 220px; height: 147px; overflow: hidden;">
<img src="https://media-cdn.tripadvisor.com/media/photo-s/01/1d/5c/0e/view-from-ocean-beach.jpg" width="220" height="206" alt="San Diego Restaurants" style="position: absolute; top: -29px; left: -0px; clip: rect(29px 220px 176px 0px);"/>
</div>
</a>
</div>
</div>
</div>
<div class="geo_wrap">
<div class="geo_entry">
<div class="geo_info">
<div class="geo_rank">10</div>
<div class="geo_name">
<a href="/Restaurants-g60956-San_Antonio_Texas.html">San Antonio Restaurants</a>
</div>
</div>
<div class="geo_image">
<a href="/Restaurants-g60956-San_Antonio_Texas.html">
<div style="position: relative; width: 220px; height: 147px; overflow: hidden;">
<img src="https://media-cdn.tripadvisor.com/media/photo-s/03/9b/30/1e/san-antonio.jpg" width="220" height="165" alt="San Antonio Restaurants" style="position: absolute; top: -9px; left: -0px; clip: rect(9px 220px 156px 0px);"/>
</div>
</a>
</div>
</div>
</div>
<div class="geo_wrap">
<div class="geo_entry">
<div class="geo_info">
<div class="geo_rank">11</div>
<div class="geo_name">
<a href="/Restaurants-g34438-Miami_Florida.html">Miami Restaurants</a>
</div>
</div>
<div class="geo_image">
<a href="/Restaurants-g34438-Miami_Florida.html">
<div style="position: relative; width: 220px; height: 147px; overflow: hidden;">
<img src="https://media-cdn.tripadvisor.com/media/photo-s/01/76/b5/b5/downtown-miami.jpg" width="220" height="206" alt="Miami Restaurants" style="position: absolute; top: -29px; left: -0px; clip: rect(29px 220px 176px 0px);"/>
</div>
</a>
</div>
</div>
</div>
<div class="geo_wrap">
<div class="geo_entry">
<div class="geo_info">
<div class="geo_rank">12</div>
<div class="geo_name">
<a href="/Restaurants-g55711-Dallas_Texas.html">Dallas Restaurants</a>
</div>
</div>
<div class="geo_image">
<a href="/Restaurants-g55711-Dallas_Texas.html">
<div style="position: relative; width: 220px; height: 147px; overflow: hidden;">
<img src="https://media-cdn.tripadvisor.com/media/photo-s/03/9b/2f/74/dallas.jpg" width="220" height="165" alt="Dallas Restaurants" style="position: absolute; top: -9px; left: -0px; clip: rect(9px 220px 156px 0px);"/>
</div>
</a>
</div>
</div>
</div>
</div> <div class="geos_row">
<div class="geo_wrap">
<div class="geo_entry">
<div class="geo_info">
<div class="geo_rank">13</div>
<div class="geo_name">
<a href="/Restaurants-g52024-Portland_Oregon.html">Portland Restaurants</a>
</div>
</div>
<div class="geo_image">
<a href="/Restaurants-g52024-Portland_Oregon.html">
<div style="position: relative; width: 220px; height: 147px; overflow: hidden;">
<img src="https://media-cdn.tripadvisor.com/media/photo-s/06/d7/dc/de/bigphotoforportland.jpg" width="220" height="165" alt="Portland Restaurants" style="position: absolute; top: -9px; left: -0px; clip: rect(9px 220px 156px 0px);"/>
</div>
</a>
</div>
</div>
</div>
<div class="geo_wrap">
<div class="geo_entry">
<div class="geo_info">
<div class="geo_rank">14</div>
<div class="geo_name">
<a href="/Restaurants-g60898-Atlanta_Georgia.html">Atlanta Restaurants</a>
</div>
</div>
<div class="geo_image">
<a href="/Restaurants-g60898-Atlanta_Georgia.html">
<div style="position: relative; width: 220px; height: 147px; overflow: hidden;">
<img src="https://media-cdn.tripadvisor.com/media/photo-s/03/9b/2f/35/atlanta.jpg" width="220" height="165" alt="Atlanta Restaurants" style="position: absolute; top: -9px; left: -0px; clip: rect(9px 220px 156px 0px);"/>
</div>
</a>
</div>
</div>
</div>
<div class="geo_wrap">
<div class="geo_entry">
<div class="geo_info">
<div class="geo_rank">15</div>
<div class="geo_name">
<a href="/Restaurants-g30196-Austin_Texas.html">Austin Restaurants</a>
</div>
</div>
<div class="geo_image">
<a href="/Restaurants-g30196-Austin_Texas.html">
<div style="position: relative; width: 220px; height: 147px; overflow: hidden;">
<img src="https://media-cdn.tripadvisor.com/media/photo-s/01/26/05/78/austin-texas.jpg" width="220" height="206" alt="Austin Restaurants" style="position: absolute; top: -29px; left: -0px; clip: rect(29px 220px 176px 0px);"/>
</div>
</a>
</div>
</div>
</div>
<div class="geo_wrap">
<div class="geo_entry">
<div class="geo_info">
<div class="geo_rank">16</div>
<div class="geo_name">
<a href="/Restaurants-g60878-Seattle_Washington.html">Seattle Restaurants</a>
</div>
</div>
<div class="geo_image">
<a href="/Restaurants-g60878-Seattle_Washington.html">
<div style="position: relative; width: 220px; height: 147px; overflow: hidden;">
<img src="https://media-cdn.tripadvisor.com/media/photo-s/01/86/aa/15/seattle.jpg" width="220" height="206" alt="Seattle Restaurants" style="position: absolute; top: -29px; left: -0px; clip: rect(29px 220px 176px 0px);"/>
</div>
</a>
</div>
</div>
</div>
</div> <div class="geos_row">
<div class="geo_wrap">
<div class="geo_entry">
<div class="geo_info">
<div class="geo_rank">17</div>
<div class="geo_name">
<a href="/Restaurants-g34515-Orlando_Florida.html">Orlando Restaurants</a>
</div>
</div>
<div class="geo_image">
<a href="/Restaurants-g34515-Orlando_Florida.html">
<div style="position: relative; width: 220px; height: 147px; overflow: hidden;">
<img src="https://media-cdn.tripadvisor.com/media/photo-s/03/9b/2d/f3/orlando.jpg" width="220" height="165" alt="Orlando Restaurants" style="position: absolute; top: -9px; left: -0px; clip: rect(9px 220px 156px 0px);"/>
</div>
</a>
</div>
</div>
</div>
<div class="geo_wrap">
<div class="geo_entry">
<div class="geo_info">
<div class="geo_rank">18</div>
<div class="geo_name">
<a href="/Restaurants-g31310-Phoenix_Arizona.html">Phoenix Restaurants</a>
</div>
</div>
<div class="geo_image">
<a href="/Restaurants-g31310-Phoenix_Arizona.html">
<div style="position: relative; width: 220px; height: 147px; overflow: hidden;">
<img src="https://media-cdn.tripadvisor.com/media/photo-s/03/9b/30/00/phoenix.jpg" width="220" height="165" alt="Phoenix Restaurants" style="position: absolute; top: -9px; left: -0px; clip: rect(9px 220px 156px 0px);"/>
</div>
</a>
</div>
</div>
</div>
<div class="geo_wrap">
<div class="geo_entry">
<div class="geo_info">
<div class="geo_rank">19</div>
<div class="geo_name">
<a href="/Restaurants-g29222-Oahu_Hawaii.html">Oahu Restaurants</a>
</div>
</div>
<div class="geo_image">
<a href="/Restaurants-g29222-Oahu_Hawaii.html">
<div style="position: relative; width: 220px; height: 147px; overflow: hidden;">
<img src="https://media-cdn.tripadvisor.com/media/photo-s/03/9b/2f/f2/oahu.jpg" width="220" height="165" alt="Oahu Restaurants" style="position: absolute; top: -9px; left: -0px; clip: rect(9px 220px 156px 0px);"/>
</div>
</a>
</div>
</div>
</div>
<div class="geo_wrap">
<div class="geo_entry">
<div class="geo_info">
<div class="geo_rank">20</div>
<div class="geo_name">
<a href="/Restaurants-g33388-Denver_Colorado.html">Denver Restaurants</a>
</div>
</div>
<div class="geo_image">
<a href="/Restaurants-g33388-Denver_Colorado.html">
<div style="position: relative; width: 220px; height: 147px; overflow: hidden;">
<img src="https://media-cdn.tripadvisor.com/media/photo-s/01/02/22/ff/on-top-of-mount-evans.jpg" width="220" height="183" alt="Denver Restaurants" style="position: absolute; top: -18px; left: -0px; clip: rect(18px 220px 165px 0px);"/>
</div>
</a>
</div>
</div>
</div>
</div> <div class="geos_row">
</div> </div> </div> </div> <div class="deckTools btm">
<div class="unified pagination ">
<span class="nav previous disabled">
Previous
</span>
<a data-page-number="2" data-offset="20" href="/Restaurants-g191-United_States.html#LOCATION_LIST" class="nav next rndBtn ui_button primary taLnk" onclick="      ta.setEvtCookie('STANDARD_PAGINATION', 'next', '2', 0, this.href);
  ">
Next
</a>
<div class="pageNumbers">
<span data-page-number="1" data-offset="0" class="pageNum current" onclick="ta.trackEventOnPage('STANDARD_PAGINATION', 'curpage', '1', 0)">1</span>
<a data-page-number="2" data-offset="20" href="/Restaurants-g191-United_States.html#LOCATION_LIST" class="pageNum taLnk" onclick="      ta.setEvtCookie('STANDARD_PAGINATION', 'page', '2', 0, this.href);
  ">
2
</a>
<a data-page-number="3" data-offset="40" href="/Restaurants-g191-United_States.html#LOCATION_LIST" class="pageNum taLnk" onclick="      ta.setEvtCookie('STANDARD_PAGINATION', 'page', '3', 0, this.href);
  ">
3
</a>
<a data-page-number="4" data-offset="60" href="/Restaurants-g191-United_States.html#LOCATION_LIST" class="pageNum taLnk" onclick="      ta.setEvtCookie('STANDARD_PAGINATION', 'page', '4', 0, this.href);
  ">
4
</a>
<a data-page-number="5" data-offset="80" href="/Restaurants-g191-United_States.html#LOCATION_LIST" class="pageNum taLnk" onclick="      ta.setEvtCookie('STANDARD_PAGINATION', 'page', '5', 0, this.href);
  ">
5
</a>
<a data-page-number="6" data-offset="100" href="/Restaurants-g191-United_States.html#LOCATION_LIST" class="pageNum taLnk" onclick="      ta.setEvtCookie('STANDARD_PAGINATION', 'page', '6', 0, this.href);
  ">
6
</a>
<span class="separator">&hellip;</span>
</div>
</div>
<script>
ta.util.element.trackWhenScrolledIntoView('.unified.pagination', ['STANDARD_PAGINATION_VISIBLE', 'numPages', '1161', 0]);
</script>
</div> <div class="seeinforow">
<div class="olnx topbot">
<table class="tablelinks">
<tr>
<td>
<span class="ui_icon hotels"></span>
</td>
<td class="link">
<a href="/Hotels-g191-United_States-Hotels.html">See top hotels in United States</a>
</td>
<td>
<span class="ui_icon attractions"></span>
</td>
<td class="link">
<a href="/Attractions-g191-Activities-United_States.html">See top things to do in United States</a>
</td>
</tr>
</table>
</div>
</div>
</div>
<div class="clearFix"></div>
<div id='lazyload_898597902_0'><!-- lazy loaded --></div>
'''

# Parse the HTML
soup = BeautifulSoup(html_snippet, 'html.parser')

# Find all <a> tags with 'href' attribute containing the pattern '/Restaurants-g'
city_links = soup.find_all('a', href=re.compile(r'/Restaurants-g\d+'))

# Extract city names and codes
england_city_code = {}
for link in city_links:
    # Extracting the city name and code
    match = re.search(r'g(\d+)-([A-Za-z_]+)_', link['href'])
    if match:
        city_code = match.group(1)
        city_name = match.group(2).replace('_', ' ')
        england_city_code[city_name] = city_code

# %%
# Convert the dictionary to a JSON string
json_data = json.dumps(england_city_code, indent=4)

# Saving the JSON data to a file
with open('us_city_codes.json', 'w') as file:
    file.write(json_data)

# %%
england_city_code
# Out:
# {'New York City New': '60763',
#  'Los Angeles': '32655',
#  'Chicago': '35805',
#  'Houston': '56003',
#  'Brooklyn New': '60827',
#  'San Francisco': '60713',
#  'Las Vegas': '45963',
#  'Philadelphia': '60795',
#  'San Diego': '60750',
#  'San Antonio': '60956',
#  'Miami': '34438',
#  'Dallas': '55711',
#  'Portland': '52024',
#  'Atlanta': '60898',
#  'Austin': '30196',
#  'Seattle': '60878',
#  'Orlando': '34515',
#  'Phoenix': '31310',
#  'Oahu': '29222',
#  'Denver': '33388',
#  'United': '191'}
